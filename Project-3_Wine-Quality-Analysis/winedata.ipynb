# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# /content/drive/MyDrive/ml/wine_quality_merged.csv

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/MLproject /wine_quality_merged.csv")

# %%
data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 0      9.4        5  red
# 1      9.8        5  red
# ...

# %%
data.shape
# Out:
# (6497, 13)

# %%
data.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (6497, 13)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="whitegrid")
sns.histplot(data["fixed acidity"],kde=True, color="blue")
plt.title("Distribution of fixed acidity ")
plt.show()

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'type'],
#       dtype='object')

# %%
sns.set_theme(style="whitegrid")
sns.histplot(data["alcohol"],kde=True, color="Red")
plt.title("Distribution of alcohol  ")
plt.show()

# %%
sns.countplot(data=data,x="quality",hue="type",palette="Set2")
plt.show()

# %%
sns.boxplot(data["pH"])
plt.show()

# %%
sns.boxplot(data=data,x="chlorides",y="pH",color="Green" )
# Out:
# <Axes: xlabel='chlorides', ylabel='pH'>

# %%
plt.figure(figsize=(30,10))
sns.scatterplot(data=data,x="pH",y="density" ,hue="quality",palette="Set2" )
plt.show()

# %%
data["type"].unique()
# Out:
# array([0, 1])

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data=data.corr(), annot=True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["type"]=le.fit_transform(data["type"])

# %%
#train test split
from sklearn.model_selection import train_test_split

# %%
x=data.drop("type",axis=1)
y=data["type"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#desicion tree
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred_dtc=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print("accuracy",accuracy_score(y_test,y_pred_dtc))
# Out:
# accuracy 0.9823076923076923

# %%
cm=confusion_matrix(y_test,y_pred_dtc)

# %%
sns.heatmap(cm,annot=True,fmt="d")
plt.show()

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred_rf=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print("accuracy",accuracy_score(y_test,y_pred_rf))
# Out:
# accuracy 0.9953846153846154

# %%
cm=confusion_matrix(y_test,y_pred_rf)

# %%
sns.heatmap(cm,annot=True,fmt="d")
plt.show()

# %%
#Xg boost
from xgboost import XGBClassifier
xg=XGBClassifier()
xg.fit(x_train,y_train)
y_pred_xg=xg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print("accuracy",accuracy_score(y_test,y_pred_xg))
# Out:
# accuracy 0.9946153846153846

# %%
cm=confusion_matrix(y_test,y_pred_xg)

# %%
sns.heatmap(cm,annot=True,fmt="d")
plt.show()

# %%
importances=xg.feature_importances_
feature=x.columns

# %%
fea_imp=pd.DataFrame({"Feature":feature,"Importance":importances})

# %%
fea_imp.head()
# Out:
#             Feature  Importance
# 0     fixed acidity    0.026950
# 1  volatile acidity    0.063866
# 2       citric acid    0.012089
# 3    residual sugar    0.012533
# 4         chlorides    0.428246

# %%
fea_imp=fea_imp.sort_values(by="Importance",ascending=False)

# %%
fea_imp.head()
# Out:
#                 Feature  Importance
# 4             chlorides    0.428246
# 6  total sulfur dioxide    0.379279
# 1      volatile acidity    0.063866
# 0         fixed acidity    0.026950
# 7               density    0.021887

# %%
fea_imp=fea_imp.sort_values(by="Importance",ascending=False).head(5)

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=fea_imp,x="Feature",y="Importance")
plt.show()

# %%
import joblib

# %%
joblib.dump(xg,"wine_type_dtc.pkl")
['wine_type_dtc.pk']
# Out:
# ['wine_type_dtc.pk']

# %%
from google.colab import files
files.download("wine_type_dtc.pkl")

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9c9e91e0-e8ff-4a06-bf87-ed042fae9fb0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c9e91e0-e8ff-4a06-bf87-ed042fae9fb0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model=joblib.load("wine_type_dtc.pkl")
